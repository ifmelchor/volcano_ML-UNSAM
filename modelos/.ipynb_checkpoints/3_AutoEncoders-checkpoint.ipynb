# %%
import os, sys
os.environ["CUDA_VISIBLE_DEVICES"]="0,1"

import numpy as np
import pandas as pd
from collections import Counter

import matplotlib.pyplot as plt

from sklearn.manifold import TSNE
from sklearn.mixture import GaussianMixture
from sklearn.preprocessing import StandardScaler

import tensorflow as tf
from tensorflow import keras
# tf.config.list_physical_devices()

sys.path.append( '..' )
from utils import LP_PSDs, plot_labels, plot_some_LP, data_preprocesados
# Out:
#  instala AntroPy [https://raphaelvallat.com/antropy] pip3 install antropy

# %% [markdown]
# Hasta ahora hemos visto que la combinación TSNE+GMM nos da unos resultados que permite entrenar un clasificador con muy buena precision.
# Sin embargo, no hemos discutido sobre la extracción de parametros que, de alguna forma, es la base de nuestros resultados.
#
# EL objetivo de este cuaderno es aplicar Redes Nauronales, y en particular AutoEncoders, para la extracción de parametros que permita mejorar la selección de clusters en el TSNE+GMM.
#
# Vamos a trabajar en el dominio espectral de la señal. Así que aplicaremos una nfft que permita describir el contenido espectral de todas las señales con el mismo tamaño. De esta forma, cada señal vendra parametrizada por su PSD que tiene un tamaño dado por la fq_size.

# %%
x_all, (x_train, x_test) = LP_PSDs(test_size=0.5)
fq_size = x_train.shape[1]

X_all = x_all.reshape(x_all.shape[0], fq_size, 1)
X_test = x_test.reshape(x_test.shape[0], fq_size, 1)
X_train =x_train.reshape(x_train.shape[0], fq_size, 1)

# %% [markdown]
# ## 1. Simple AutoEncoder

# %%
keras.backend.clear_session()
input_img = keras.layers.Input(shape=(fq_size,))
encoded = keras.layers.Dense(5, activation='relu')(input_img)
decoded = keras.layers.Dense(fq_size, activation='sigmoid')(encoded)
AE = keras.models.Model(input_img, decoded)
keras.utils.plot_model(AE, show_shapes=True)
AE.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 97)]              0
# _________________________________________________________________
# dense (Dense)                (None, 5)                 490
# _________________________________________________________________
# dense_1 (Dense)              (None, 97)                582
# =================================================================
# Total params: 1,072
# Trainable params: 1,072
# Non-trainable params: 0
# _________________________________________________________________

# %%
AE.compile(optimizer='adam', loss='binary_crossentropy')
history = AE.fit(x_train, x_train,
                epochs=200,
                batch_size=40,
                shuffle=True,
                validation_data=(x_test, x_test)
                )
# Out:
# Epoch 1/200
# 14/14 [==============================] - 1s 12ms/step - loss: 0.6897 - val_loss: 0.6841
# Epoch 2/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6784 - val_loss: 0.6701
# Epoch 3/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6614 - val_loss: 0.6488
# Epoch 4/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6365 - val_loss: 0.6199
# Epoch 5/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6042 - val_loss: 0.5832
# Epoch 6/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5637 - val_loss: 0.5393
# Epoch 7/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5183 - val_loss: 0.4952
# Epoch 8/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4763 - val_loss: 0.4592
# Epoch 9/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4439 - val_loss: 0.4335
# Epoch 10/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4209 - val_loss: 0.4154
# Epoch 11/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4049 - val_loss: 0.4036
# Epoch 12/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3942 - val_loss: 0.3956
# Epoch 13/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3874 - val_loss: 0.3901
# Epoch 14/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3824 - val_loss: 0.3858
# Epoch 15/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3787 - val_loss: 0.3825
# Epoch 16/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3756 - val_loss: 0.3797
# Epoch 17/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3730 - val_loss: 0.3772
# Epoch 18/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3709 - val_loss: 0.3751
# Epoch 19/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3689 - val_loss: 0.3733
# Epoch 20/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3671 - val_loss: 0.3716
# Epoch 21/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3655 - val_loss: 0.3701
# Epoch 22/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3641 - val_loss: 0.3686
# Epoch 23/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3627 - val_loss: 0.3673
# Epoch 24/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3615 - val_loss: 0.3662
# Epoch 25/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3604 - val_loss: 0.3651
# Epoch 26/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3593 - val_loss: 0.3639
# Epoch 27/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3583 - val_loss: 0.3628
# Epoch 28/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3573 - val_loss: 0.3619
# Epoch 29/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3564 - val_loss: 0.3609
# Epoch 30/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3555 - val_loss: 0.3600
# Epoch 31/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3545 - val_loss: 0.3587
# Epoch 32/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3536 - val_loss: 0.3578
# Epoch 33/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3528 - val_loss: 0.3569
# Epoch 34/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3520 - val_loss: 0.3561
# Epoch 35/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3513 - val_loss: 0.3554
# Epoch 36/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3505 - val_loss: 0.3547
# Epoch 37/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3497 - val_loss: 0.3539
# Epoch 38/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3490 - val_loss: 0.3532
# Epoch 39/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3483 - val_loss: 0.3526
# Epoch 40/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3476 - val_loss: 0.3518
# Epoch 41/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3468 - val_loss: 0.3511
# Epoch 42/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3461 - val_loss: 0.3503
# Epoch 43/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3454 - val_loss: 0.3496
# Epoch 44/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3447 - val_loss: 0.3488
# Epoch 45/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3441 - val_loss: 0.3481
# Epoch 46/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3435 - val_loss: 0.3477
# Epoch 47/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3427 - val_loss: 0.3470
# Epoch 48/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3421 - val_loss: 0.3461
# Epoch 49/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3415 - val_loss: 0.3455
# Epoch 50/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3409 - val_loss: 0.3449
# Epoch 51/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3403 - val_loss: 0.3444
# Epoch 52/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3397 - val_loss: 0.3440
# Epoch 53/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3391 - val_loss: 0.3436
# Epoch 54/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3387 - val_loss: 0.3432
# Epoch 55/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3382 - val_loss: 0.3428
# Epoch 56/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3377 - val_loss: 0.3422
# Epoch 57/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3371 - val_loss: 0.3417
# Epoch 58/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3366 - val_loss: 0.3411
# Epoch 59/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3362 - val_loss: 0.3405
# Epoch 60/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3357 - val_loss: 0.3401
# Epoch 61/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3351 - val_loss: 0.3399
# Epoch 62/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3348 - val_loss: 0.3395
# Epoch 63/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3343 - val_loss: 0.3390
# Epoch 64/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3339 - val_loss: 0.3385
# Epoch 65/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3335 - val_loss: 0.3381
# Epoch 66/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3331 - val_loss: 0.3376
# Epoch 67/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3327 - val_loss: 0.3373
# Epoch 68/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3323 - val_loss: 0.3370
# Epoch 69/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3320 - val_loss: 0.3367
# Epoch 70/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3316 - val_loss: 0.3364
# Epoch 71/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3312 - val_loss: 0.3360
# Epoch 72/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3308 - val_loss: 0.3354
# Epoch 73/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3305 - val_loss: 0.3351
# Epoch 74/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3301 - val_loss: 0.3349
# Epoch 75/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3298 - val_loss: 0.3346
# Epoch 76/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3295 - val_loss: 0.3343
# Epoch 77/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3291 - val_loss: 0.3340
# Epoch 78/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3289 - val_loss: 0.3338
# Epoch 79/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3285 - val_loss: 0.3333
# Epoch 80/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3282 - val_loss: 0.3329
# Epoch 81/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3279 - val_loss: 0.3326
# Epoch 82/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3275 - val_loss: 0.3323
# Epoch 83/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3272 - val_loss: 0.3320
# Epoch 84/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3270 - val_loss: 0.3317
# Epoch 85/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3266 - val_loss: 0.3314
# Epoch 86/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3263 - val_loss: 0.3313
# Epoch 87/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3259 - val_loss: 0.3310
# Epoch 88/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3256 - val_loss: 0.3307
# Epoch 89/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3253 - val_loss: 0.3302
# Epoch 90/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3250 - val_loss: 0.3299
# Epoch 91/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3247 - val_loss: 0.3297
# Epoch 92/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3244 - val_loss: 0.3294
# Epoch 93/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3241 - val_loss: 0.3291
# Epoch 94/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3238 - val_loss: 0.3289
# Epoch 95/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3234 - val_loss: 0.3285
# Epoch 96/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3231 - val_loss: 0.3282
# Epoch 97/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3229 - val_loss: 0.3279
# Epoch 98/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3225 - val_loss: 0.3278
# Epoch 99/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3222 - val_loss: 0.3275
# Epoch 100/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3219 - val_loss: 0.3271
# Epoch 101/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3216 - val_loss: 0.3267
# Epoch 102/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3213 - val_loss: 0.3265
# Epoch 103/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3210 - val_loss: 0.3260
# Epoch 104/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3207 - val_loss: 0.3258
# Epoch 105/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3204 - val_loss: 0.3255
# Epoch 106/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3201 - val_loss: 0.3253
# Epoch 107/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3198 - val_loss: 0.3250
# Epoch 108/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3194 - val_loss: 0.3246
# Epoch 109/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3191 - val_loss: 0.3242
# Epoch 110/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3188 - val_loss: 0.3238
# Epoch 111/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3185 - val_loss: 0.3235
# Epoch 112/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3182 - val_loss: 0.3233
# Epoch 113/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3179 - val_loss: 0.3230
# Epoch 114/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3176 - val_loss: 0.3228
# Epoch 115/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3172 - val_loss: 0.3225
# Epoch 116/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3169 - val_loss: 0.3223
# Epoch 117/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3166 - val_loss: 0.3219
# Epoch 118/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3163 - val_loss: 0.3215
# Epoch 119/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3160 - val_loss: 0.3213
# Epoch 120/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3157 - val_loss: 0.3210
# Epoch 121/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3154 - val_loss: 0.3207
# Epoch 122/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3150 - val_loss: 0.3203
# Epoch 123/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3147 - val_loss: 0.3201
# Epoch 124/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3144 - val_loss: 0.3198
# Epoch 125/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3141 - val_loss: 0.3194
# Epoch 126/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3138 - val_loss: 0.3191
# Epoch 127/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3136 - val_loss: 0.3187
# Epoch 128/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3132 - val_loss: 0.3184
# Epoch 129/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3129 - val_loss: 0.3181
# Epoch 130/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3126 - val_loss: 0.3177
# Epoch 131/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3123 - val_loss: 0.3175
# Epoch 132/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3120 - val_loss: 0.3172
# Epoch 133/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3117 - val_loss: 0.3170
# Epoch 134/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3115 - val_loss: 0.3168
# Epoch 135/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3112 - val_loss: 0.3165
# Epoch 136/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3109 - val_loss: 0.3162
# Epoch 137/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3106 - val_loss: 0.3157
# Epoch 138/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3103 - val_loss: 0.3155
# Epoch 139/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3100 - val_loss: 0.3152
# Epoch 140/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3098 - val_loss: 0.3149
# Epoch 141/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3095 - val_loss: 0.3147
# Epoch 142/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3092 - val_loss: 0.3145
# Epoch 143/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3090 - val_loss: 0.3143
# Epoch 144/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3087 - val_loss: 0.3139
# Epoch 145/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3084 - val_loss: 0.3136
# Epoch 146/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3081 - val_loss: 0.3134
# Epoch 147/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3079 - val_loss: 0.3132
# Epoch 148/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3076 - val_loss: 0.3129
# Epoch 149/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3074 - val_loss: 0.3128
# Epoch 150/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3072 - val_loss: 0.3125
# Epoch 151/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3069 - val_loss: 0.3122
# Epoch 152/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3066 - val_loss: 0.3119
# Epoch 153/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3064 - val_loss: 0.3116
# Epoch 154/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3062 - val_loss: 0.3114
# Epoch 155/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3059 - val_loss: 0.3112
# Epoch 156/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3057 - val_loss: 0.3109
# Epoch 157/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3054 - val_loss: 0.3107
# Epoch 158/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3052 - val_loss: 0.3105
# Epoch 159/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3050 - val_loss: 0.3103
# Epoch 160/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3048 - val_loss: 0.3101
# Epoch 161/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3046 - val_loss: 0.3099
# Epoch 162/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3044 - val_loss: 0.3097
# Epoch 163/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3042 - val_loss: 0.3095
# Epoch 164/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3040 - val_loss: 0.3093
# Epoch 165/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3038 - val_loss: 0.3091
# Epoch 166/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3036 - val_loss: 0.3088
# Epoch 167/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3034 - val_loss: 0.3087
# Epoch 168/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3032 - val_loss: 0.3085
# Epoch 169/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3030 - val_loss: 0.3084
# Epoch 170/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3028 - val_loss: 0.3082
# Epoch 171/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3026 - val_loss: 0.3081
# Epoch 172/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3024 - val_loss: 0.3078
# Epoch 173/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3023 - val_loss: 0.3077
# Epoch 174/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3021 - val_loss: 0.3076
# Epoch 175/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3019 - val_loss: 0.3075
# Epoch 176/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3017 - val_loss: 0.3072
# Epoch 177/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3016 - val_loss: 0.3069
# Epoch 178/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3014 - val_loss: 0.3067
# Epoch 179/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3013 - val_loss: 0.3065
# Epoch 180/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3011 - val_loss: 0.3063
# Epoch 181/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3010 - val_loss: 0.3062
# Epoch 182/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3008 - val_loss: 0.3061
# Epoch 183/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3007 - val_loss: 0.3060
# Epoch 184/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3005 - val_loss: 0.3058
# Epoch 185/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3004 - val_loss: 0.3057
# Epoch 186/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3003 - val_loss: 0.3055
# Epoch 187/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3001 - val_loss: 0.3054
# Epoch 188/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3000 - val_loss: 0.3054
# Epoch 189/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2999 - val_loss: 0.3051
# Epoch 190/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2997 - val_loss: 0.3050
# Epoch 191/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2996 - val_loss: 0.3049
# Epoch 192/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2995 - val_loss: 0.3048
# Epoch 193/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2994 - val_loss: 0.3046
# Epoch 194/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2993 - val_loss: 0.3044
# Epoch 195/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2992 - val_loss: 0.3043
# Epoch 196/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2990 - val_loss: 0.3042
# Epoch 197/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2989 - val_loss: 0.3041
# Epoch 198/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2988 - val_loss: 0.3040
# Epoch 199/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2987 - val_loss: 0.3038
# Epoch 200/200
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2986 - val_loss: 0.3038

# %%
df = pd.DataFrame(history.history)
df.plot(figsize=(15,10))
plt.title('Epoch vs val_loss', fontsize= 24)
plt.xlabel('Epoch', fontsize= 18)
plt.ylabel('val_loss', fontsize= 18)
plt.tick_params(axis='both', which='major', labelsize=14, length=6, width=3)
plt.savefig('img/SAE_training.png', bbox_inches = 'tight')
plt.grid(True)
plt.show()

# %%
x_pred = AE.predict(x_test)
x_index = np.arange(x_test.shape[0])
x_some = x_index[np.random.choice(x_test.shape[0], 9, replace=False)]

plt.figure(figsize=(20, 10))
for i, n in enumerate(x_some):
    ax = plt.subplot(3, 3, i + 1)
    ax.plot(x_test[n,:], color='k')
    ax.plot(x_pred[n,:]/x_pred[n,:].max(), color='r')
    ax.annotate(r'LP$_{%i}$' % n, (80, 0.8), bbox=dict(boxstyle="round", fc='w', ec="k", lw=0.8), size=16)
    ax.tick_params(axis='both', which='major', labelsize=16, length=6, width=3)
plt.savefig('img/SAE_predict.png', bbox_inches = 'tight')
plt.show()
plt.close()

# %%
encoder = keras.models.Model(input_img, encoded)
x_encoder = encoder.predict(x_all)
x_encoder.shape
# Out:
# (1044, 5)

# %% [markdown]
# ## 2. Evaluación de los nuevos parametros

# %%
ss = StandardScaler()
X_ec = ss.fit_transform(x_encoder)

# %%
tsne = TSNE(init="pca")
X_valid_2D = tsne.fit_transform(X_ec)
gmm = GaussianMixture(n_components=7, n_init=10, random_state=5).fit(X_valid_2D)
y_predict = gmm.predict(X_valid_2D)
prob = gmm.predict_proba(X_valid_2D)

labels = list(Counter(y_predict).keys())

print(' Akaike information criterion (AIC): ', f'{gmm.aic(X_valid_2D):.0f}')
print(' Bayesian information criterion (BIC): ', f'{gmm.bic(X_valid_2D):.0f}')
print('\n', Counter(y_predict))
# Out:
# C:\Users\Pablo\anaconda3\envs\tf\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# C:\Users\Pablo\anaconda3\envs\tf\lib\site-packages\sklearn\manifold\_t_sne.py:982: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   warnings.warn(
#  Akaike information criterion (AIC):  17597
#  Bayesian information criterion (BIC):  17800
#
#  Counter({3: 200, 1: 182, 0: 171, 4: 138, 5: 125, 2: 115, 6: 113})

# %%
plot_labels(X_valid_2D, y_predict, cmap='rainbow', title='TSNE+GMM\n Simple AutoEncoder', show_centroid=True ,ellipse=(gmm.means_, gmm.covariances_))
plt.savefig('img/SAE_graph.png', bbox_inches = 'tight')
plt.show()
plt.close()

# %%
y, y_best = np.where(prob>0.99)
y_best_label = list(Counter(y_best).keys())
y_best_label.sort()

print(f'Total: {len(y)}') 
print('Label, nro_LPs')
print('---------------')
for n in y_best_label:
    i = Counter(y_best)[n]
    print(f'{n:^5}', f'{i:^7}')
# Out:
# Total: 176
# Label, nro_LPs
# ---------------
#   1     72
#   3     86
#   4      7
#   6     11

# %% [markdown]
# En resumen, si bien estos nuevos parametros son capaces de reproducir el espectro de las señales mediante un decoder específico, no notamos ninguna mejora al aplicar el procedimiento TSNE+GMM.
#
# Por un lado, las métricas AIC y BIC muestran valores mayores al procedimiento original. Por otro, el numero de señales con una probabilidad de pertenencia a clases mayor al 99% es considerablemente menor.

# %%
plot_some_LP(y_best, 3, rand_int=3, y_index=y)
plt.savefig('img/SAE_LP1.png', bbox_inches = 'tight')
plt.show()
plt.close()
# Out:
# 3 [ 606  983 1016]

# %% [markdown]
# ## 3. Combinación de parametros

# %% [markdown]
# Dado que explotar la parametrización de las señales mediante autoencoders no ha dado un resultado mejor que en el procesamiento anterior. La idea es combinar la información para obtener una base de datos más completa. En particular vamos a tener 15 parametros más, es decir, 31 parametros por señal.

# %%
X_raw = data_preprocesados()
X_all = np.hstack((X_raw, X_ec))
print(X_all.shape)
# Out:
# (1044, 21)

# %%
tsne = TSNE(init='pca')
X_all_2D = tsne.fit_transform(X_all)

gmm = GaussianMixture(n_components=7, n_init=10).fit(X_all_2D)
y_predict = gmm.predict(X_all_2D)
prob = gmm.predict_proba(X_all_2D)

labels = list(Counter(y_predict).keys())

print(' Akaike information criterion (AIC): ', f'{gmm.aic(X_all_2D):.0f}')
print(' Bayesian information criterion (BIC): ', f'{gmm.bic(X_all_2D):.0f}')
print('\n', Counter(y_predict))
# Out:
# C:\Users\Pablo\anaconda3\envs\tf\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# C:\Users\Pablo\anaconda3\envs\tf\lib\site-packages\sklearn\manifold\_t_sne.py:982: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   warnings.warn(
#  Akaike information criterion (AIC):  17521
#  Bayesian information criterion (BIC):  17724
#
#  Counter({4: 232, 1: 159, 3: 152, 5: 138, 2: 131, 6: 120, 0: 112})

# %%
plot_labels(X_all_2D, y_predict, cmap='rainbow', title='TSNE+GMM\n+AutoEncoder', show_centroid=True ,ellipse=(gmm.means_, gmm.covariances_))
plt.savefig('img/SAE_params_comb.png', bbox_inches = 'tight')
plt.show()
plt.close()

# %%
plot_some_LP(y_predict, 6, rand_int=3)
plt.savefig('img/SAE_params_comb_LP1.png', bbox_inches = 'tight')
plt.show()
plt.close()
# Out:
# 6 [579 668 583]
# C:\Users\Pablo\anaconda3\envs\tf\lib\site-packages\scipy\signal\spectral.py:1964: UserWarning: nperseg = 1024 is greater than input length  = 800, using nperseg = 800
#   warnings.warn('nperseg = {0:d} is greater than input length '
